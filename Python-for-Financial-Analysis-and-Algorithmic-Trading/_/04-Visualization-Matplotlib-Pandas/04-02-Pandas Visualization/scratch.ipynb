# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns
plt.style.use('ggplot')

# %%
df1 = pd.read_csv('df1', index_col=0)
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv('df2')
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df1['A'].hist(bins=30)

# %%
df1['A'].plot(kind='hist', bins=30)

# %%
df1['A'].plot.hist()

# %%
df2.plot.area(alpha=0.3)

# %%
df2.plot.bar(stacked=True)

# %%
df1['A'].plot.hist(bins=50)

# %%
df1.plot.line(x=df1.index, y='B', figsize=(14, 3), lw=1)

# %%
df1.plot.scatter(x='A', y='B')

# %%
df1.plot.scatter(x='A', y='B', c='C', cmap='coolwarm', s=df1['C']*100)
# Out:
# /anaconda/envs/python3.6/lib/python3.6/site-packages/matplotlib/collections.py:853: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
df2.plot.box()

# %%
df = pd.DataFrame(data=np.random.randn(1000, 2), columns=['a', 'b'])
df.head()
# Out:
#           a         b
# 0  0.691765  0.870008
# 1  0.198000  0.224508
# 2 -1.402641 -0.361296
# 3 -1.252630  0.687851
# 4  2.154717 -1.876730

# %%
df.plot.hexbin(x='a', y='b', gridsize=25, cmap='coolwarm')

# %%
df2['a'].plot.kde()

# %%
df2['a'].plot.density()

# %%
for curr_df in [df, df1, df2]:
    curr_df.plot.kde()

# %% [markdown]
# # Time Series

# %%
mcdon = pd.read_csv('mcdonalds.csv', index_col='Date', parse_dates=True)
mcdon.head()
# Out:
#             Adj. Close  Adj. Volume
# Date
# 1970-01-02    0.209761    2825604.0
# 1970-01-05    0.213316    2210449.5
# 1970-01-06    0.214501    1951168.5
# 1970-01-07    0.213316    2728768.5
# 1970-01-08    0.213316    2242404.0

# %%
mcdon['Adj. Close'].plot()

# %%
mcdon['Adj. Volume'].plot(figsize=(16, 4))

# %%
mcdon['Adj. Close'].plot(xlim=['2007-01-01', '2009-01-01'])

# %%
mcdon['Adj. Close'].plot(xlim=['2007-01-01', '2009-01-01'], ylim=(30, 50),figsize=(16, 4))

# %%
mcdon['Adj. Close'].plot(xlim=['2007-01-01', '2009-01-01'], ylim=(30, 50), ls='--', c='orange')

# %% [markdown]
# ## formatting dates

# %%
from matplotlib import dates as dates

# %%
mcdon['Adj. Close'].plot(xlim=['2007-01-01', '2009-01-01'], ylim=(0, 50))

# %%
mcdon.index
# Out:
# DatetimeIndex(['1970-01-02', '1970-01-05', '1970-01-06', '1970-01-07',
#                '1970-01-08', '1970-01-09', '1970-01-12', '1970-01-13',
#                '1970-01-14', '1970-01-15',
#                ...
#                '2017-06-30', '2017-07-03', '2017-07-05', '2017-07-06',
#                '2017-07-07', '2017-07-10', '2017-07-11', '2017-07-12',
#                '2017-07-13', '2017-07-14'],
#               dtype='datetime64[ns]', name='Date', length=11993, freq=None)

# %%
idx = mcdon.loc['2007-01-01': '2009-01-01'].index
idx
# Out:
# DatetimeIndex(['2007-01-03', '2007-01-04', '2007-01-05', '2007-01-08',
#                '2007-01-09', '2007-01-10', '2007-01-11', '2007-01-12',
#                '2007-01-16', '2007-01-17',
#                ...
#                '2008-12-17', '2008-12-18', '2008-12-19', '2008-12-22',
#                '2008-12-23', '2008-12-24', '2008-12-26', '2008-12-29',
#                '2008-12-30', '2008-12-31'],
#               dtype='datetime64[ns]', name='Date', length=504, freq=None)

# %%
stock = mcdon.loc['2007-01-01' : '2009-01-01']['Adj. Close']

# %%
stock.head()
# Out:
# Date
# 2007-01-03    31.662754
# 2007-01-04    31.424580
# 2007-01-05    31.424580
# 2007-01-08    31.547276
# 2007-01-09    31.605015
# Name: Adj. Close, dtype: float64
